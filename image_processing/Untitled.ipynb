# %%
# from skimage import io
# img = io.read("image.ext")
# print(img.shape)

# # looking at pixel value
# import pandas as pd
# df = pd.DataFrame(img.flatten())
# filepath = 'pixel_values.xlsx'
# df.to_excel(filepath. index=False)
# print(df)

# # conversion of colors from a format into another format
# from skimage import color
# from skimage import data
# from pylab import *
# # read image
# img = io.imread("image.ext")

# # convert to HSV
# img_hsv = color.rgb2hsv(img)
# # convert back to RGB
# img_rgb = color.hsv2rgb(img_hsv)
# #show both 
# figure(0)
# io.imshow(img_hsv)
# figure(1)
# io.imshow(img_rgb)

# %%
# # drawing on images

# from skimage import io
# from skimage import draw

# # line
# img = io.imread("image.ext")
# x, y = draw.line(0, 0, 1000, 1000)
# img[x, y] = 0
# io.imshow(img)

# # rectangle
# def rectangle(x, y, w, h):
#   rr, cc = [x, x+w, x+w, x], [y, y+h, y+h, y]
#   return draw.polygon(rr, cc)

# rr, cc = rectangle(10, 10, 500, 500)
# img[rr, cc] = 1
# io.imshow(img)

# # circle
# x, y = draw.circle(500, 500, 100)
# img[x, y] = 1
# io.imshow(img)

# # beizer 
# x, y = draw.bezier_curve(0,0, 500, 500, 900, 1200, 100)
# img[x,y] = 1
# io.imshow(img)

# %%
# a = [1, 1, 1, 0, 1, 0, 0, 1]
# b = [1, 0, 1, 0, 0, 1, 0, 1] 
# # tp is set to 0 to keep count of 0
# # since 0  is positive
# # and 1 is negative
# tp = 0
# fn = 0
# for i in range(len(a)):
#     if (a[i]==0) and a[i] == b[i]:
#         tp+=1
#     elif (a[i] == 0 and b[i] == 1):
#         fn+=1
#     else:
#         pass
# # since recall score  = tp/ tp + fn
# # where tp = True positive 
# # and fn = False negative
# recall_score = tp/(tp + fn)
# print(tp)
# print(fn)
# print(recall_score)
# Out:
# 2
# 1
# 0.6666666666666666

# %%
from skimage import io
from skimage import draw
# from skimage import color
# from skimage import data
# from pylab import *

# img_rgb = color.hsv2rgb(img_hsv)

# figure(0)
# io.imshow(img_hsv)
# figure(1)
# io.imshow(img_rgb)
x, y = draw.line(0,0,1000,1000)
io.imshow([x, y])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-7bfa3498261a> in <module>
#      12 # io.imshow(img_rgb)
#      13 x, y = draw.line(0,0,1000,1000)
# ---> 14 io.imshow([x, y])
#
# ~/anaconda3/lib/python3.8/site-packages/skimage/io/_io.py in imshow(arr, plugin, **plugin_args)
#     157     if isinstance(arr, str):
#     158         arr = call_plugin('imread', arr, plugin=plugin)
# --> 159     return call_plugin('imshow', arr, plugin=plugin, **plugin_args)
#     160
#     161
#
# ~/anaconda3/lib/python3.8/site-packages/skimage/io/manage_plugins.py in call_plugin(kind, *args, **kwargs)
#     207                                (plugin, kind))
#     208
# --> 209     return func(*args, **kwargs)
#     210
#     211
#
# ~/anaconda3/lib/python3.8/site-packages/skimage/io/_plugins/matplotlib_plugin.py in imshow(image, ax, show_cbar, **kwargs)
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file = pd.read_csv("FoodBalanceSheets_E_Africa_NOFLAG.csv",encoding="latin-1")
file.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
file["Y2017"].describe()
# Out:
# count     59437.000000
# mean        140.917765
# std        1671.862359
# min       -1582.000000
# 25%           0.000000
# 50%           0.100000
# 75%           9.000000
# max      190873.000000
# Name: Y2017, dtype: float64

# %%
file.groupby("Element")["Y2017"].sum()
# Out:
# Element
# Domestic supply quantity                  2088198.10
# Export Quantity                            182338.80
# Fat supply quantity (g/capita/day)          10253.84
# Feed                                       223705.68
# Food                                      1258888.28
# Food supply (kcal/capita/day)              454681.00
# Food supply quantity (kg/capita/yr)         48690.04
# Import Quantity                            294559.09
# Losses                                     160614.00
# Other uses (non-food)                       91645.97
# Processing                                 292836.00
# Production                                2030056.89
# Protein supply quantity (g/capita/day)      11842.45
# Residuals                                   35500.00
# Seed                                        24870.14
# Stock Variation                             54316.91
# Total Population - Both sexes             1112641.00
# Tourist consumption                            91.00
# ...

# %%
file.corr()
# Out:
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.005159     -0.000209  0.006164  0.005472
# Item Code     -0.005159   1.000000     -0.024683  0.021722  0.020857
# Element Code  -0.000209  -0.024683      1.000000  0.024457  0.023889
# Y2014          0.006164   0.021722      0.024457  1.000000  0.994647
# Y2015          0.005472   0.020857      0.023889  0.994647  1.000000
# Y2016          0.005247   0.020109      0.023444  0.996081  0.995739
# Y2017          0.005006   0.021494      0.024254  0.995230  0.988048
# Y2018          0.005665   0.021314      0.024279  0.994872  0.988208
#
#                  Y2016     Y2017     Y2018
# Area Code     0.005247  0.005006  0.005665
# Item Code     0.020109  0.021494  0.021314
# Element Code  0.023444  0.024254  0.024279
# Y2014         0.996081  0.995230  0.994872
# Y2015         0.995739  0.988048  0.988208
# Y2016         1.000000  0.992785  0.992757
# ...

# %%
file.groupby("Item")[["Y2015","Y2018"]].sum()
# Out:
#                          Y2015      Y2018
# Item
# Alcohol, Non-Food      2180.00    2293.00
# Alcoholic Beverages   98783.72   97847.27
# Animal Products       11811.73   11578.61
# Animal fats          200675.72  269648.27
# Apples and products   10559.15    9640.51
# ...                        ...        ...
# Vegetables, Other    158104.08  163987.21
# Vegetal Products     107064.17  107775.39
# Wheat and products   234710.51  242645.19
# Wine                   4251.81    4039.32
# Yams                 203151.78  221272.09
#
# [119 rows x 2 columns]

# %%
file.groupby(["Element","Area"])["Y2015"].sum()["Protein supply quantity (g/capita/day)"]
# Out:
# Area
# Algeria                        377.37
# Angola                         214.15
# Benin                          271.97
# Botswana                       278.52
# Burkina Faso                   317.99
# Cabo Verde                     278.41
# Cameroon                       291.53
# Central African Republic       173.70
# Chad                           252.28
# Congo                          227.08
# Côte d'Ivoire                  232.59
# Djibouti                       269.59
# Egypt                          394.87
# Eswatini                       237.71
# Ethiopia                       259.82
# Gabon                          345.41
# Gambia                         257.67
# Ghana                          241.71
# Guinea                         227.46
# Guinea-Bissau                  168.61
# Kenya                          251.73
# Lesotho                        254.50
# Liberia                        159.43
# Madagascar                     173.05
# ...

# %%
file.groupby(["Area"])[["Area","Y2017"]].sum()
# Out:
#                                   Y2017
# Area
# Algeria                       325644.27
# Angola                        229159.57
# Benin                         124771.22
# Botswana                       22101.30
# Burkina Faso                  101855.07
# Cabo Verde                     14650.74
# Cameroon                      232030.43
# Central African Republic       29937.00
# Chad                           71594.68
# Comoros                           59.84
# Congo                          41181.68
# Côte d'Ivoire                 224599.01
# Djibouti                       22729.91
# Egypt                         866379.92
# Eswatini                       54343.33
# Ethiopia                      448683.76
# Ethiopia PDR                       0.00
# Gabon                          27979.64
# Gambia                         23154.18
# Ghana                         337599.06
# Guinea                         98138.87
# Guinea-Bissau                  19102.77
# ...

# %%
file["Y2014"].isnull().value_counts()
# Out:
# False    59354
# True      1589
# Name: Y2014, dtype: int64

# %%
S = [['him', 'sell'], [90, 28, 43]]

S[0][1][1]
# Out:
# 'e'

# %%
my_tuppy = [(2,4),(7,8),(1,5,9)]
x = my_tuppy[1][-1] 
x
# Out:
# 8

# %%
array  = np.array( [[94, 89, 63],

             [93, 92, 48],

             [92, 94, 56]])

array
array[:2,1:]
# Out:
# array([[89, 63],
#        [92, 48]])
